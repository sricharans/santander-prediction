# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler
from imblearn.pipeline import Pipeline
from lightgbm import LGBMClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from imblearn.pipeline import Pipeline
import lightgbm as lightgbmclassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from tqdm import tqdm_notebook as tqdm
import scipy.ndimage
import tensorflow as tf
from sklearn import linear_model
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Input, Dropout, Flatten, Convolution2D, MaxPooling2D, Dense, Activation, Conv1D, BatchNormalization, AveragePooling1D, Reshape
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.utils import np_utils



import warnings
warnings.filterwarnings('ignore')

# %%
import sys
# !{sys.executable} -m pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 2.4 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.0.2)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.4.1)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=16.9->scikit-optimize) (3.13)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-21.10.1 scikit-optimize-0.9.0

# %%
from skopt import BayesSearchCV

# %%
RAND_STATE = 47
np.random.seed(RAND_STATE)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Get Updated clean and split files

# %%
def get_train_test(tr = 'X_train.csv', te = 'X_test_all.csv'):
    # Returns a sample of original dataset
    # of 100k records of class 0 and all records of class 1
    # along with val and test datasets
    df = pd.read_csv(folder + tr)
    # test_df = pd.read_csv(folder + 'X_test.csv')
    test_all_df = pd.read_csv(folder + te)
    # Splitting for train and val
    X_train, X_val, y_train, y_val = train_test_split(df.iloc[:, 3:],
                                                    df.target,
                                                    test_size=0.2, 
                                                    random_state=RAND_STATE,
                                                    stratify = df['target'])
    X_test_all = test_all_df.iloc[:, 3:]
    
    class_dict = {0 : 100000,
                  1 :  y_train.value_counts()[1]}
    
    rus = RandomUnderSampler(sampling_strategy = class_dict,
                             random_state = RAND_STATE) 
    X_res, y_res = rus.fit_resample(X_train, y_train)
    X_res.to_csv(folder+'charan/X_res.csv')
    y_res.to_csv(folder+'charan/y_res.csv')
    
    del df, test_all_df
#   return X_train, X_val, y_train, y_val, X_test_all
    return X_res, X_val, y_res, y_val, X_test_all

# %% [markdown]
# ### Model Training

# %%
# XGBoost model

xgbc_grid =  {
    'n_estimators': [50,100,200],
    'max_depth': [5, 10],
    'learning_rate': [0.05,0.1]
    
}

# %%
xgbc = XGBClassifier(verbosity = 2, 
                     learning_rate = 0.01,
                     scale_pos_weight = 8,
                     random_state = RAND_STATE)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
xgbc_clf = RandomizedSearchCV(scoring = 'roc_auc',
                       estimator = xgbc,
                       param_distributions = xgbc_grid,
                       verbose = 1,
                       n_iter = 2)

# %%
xgbc_clf.fit(X_train, y_train, 
            verbose = 1, 
            early_stopping_rounds = 3, 
            eval_metric = 'auc', 
            eval_set=[(X_train, y_train), 
                      (X_val, y_val)])
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [20:59:27] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 880 extra nodes, 0 pruned nodes, max_depth=10
# [0]	validation_0-auc:0.73082	validation_1-auc:0.61880
# [20:59:32] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 870 extra nodes, 0 pruned nodes, max_depth=10
# [1]	validation_0-auc:0.76932	validation_1-auc:0.64356
# [20:59:37] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 988 extra nodes, 0 pruned nodes, max_depth=10
# [2]	validation_0-auc:0.80402	validation_1-auc:0.66272
# [20:59:41] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 960 extra nodes, 0 pruned nodes, max_depth=10
# [3]	validation_0-auc:0.82018	validation_1-auc:0.67494
# [20:59:46] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 912 extra nodes, 0 pruned nodes, max_depth=10
# [4]	validation_0-auc:0.83389	validation_1-auc:0.68463
# [20:59:51] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 766 extra nodes, 0 pruned nodes, max_depth=10
# [5]	validation_0-auc:0.84175	validation_1-auc:0.69095
# [20:59:56] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 932 extra nodes, 0 pruned nodes, max_depth=10
# [6]	validation_0-auc:0.85176	validation_1-auc:0.69751
# [21:00:01] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 792 extra nodes, 0 pruned nodes, max_depth=10
# [7]	validation_0-auc:0.85738	validation_1-auc:0.70462
# [21:00:07] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 934 extra nodes, 0 pruned nodes, max_depth=10
# [8]	validation_0-auc:0.86519	validation_1-auc:0.70939
# [21:00:13] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 780 extra nodes, 0 pruned nodes, max_depth=10
# [9]	validation_0-auc:0.87117	validation_1-auc:0.71432
# [21:00:18] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 904 extra nodes, 0 pruned nodes, max_depth=10
# [10]	validation_0-auc:0.87802	validation_1-auc:0.71872
# [21:00:23] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 748 extra nodes, 0 pruned nodes, max_depth=10
# [11]	validation_0-auc:0.88302	validation_1-auc:0.72261
# [21:00:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1030 extra nodes, 0 pruned nodes, max_depth=10
# [12]	validation_0-auc:0.88886	validation_1-auc:0.72739
# [21:00:33] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 824 extra nodes, 0 pruned nodes, max_depth=10
# [13]	validation_0-auc:0.89261	validation_1-auc:0.72908
# [21:00:38] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 772 extra nodes, 0 pruned nodes, max_depth=10
# [14]	validation_0-auc:0.89699	validation_1-auc:0.73500
# [21:00:43] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 938 extra nodes, 0 pruned nodes, max_depth=10
# [15]	validation_0-auc:0.90111	validation_1-auc:0.73717
# [21:00:49] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 848 extra nodes, 0 pruned nodes, max_depth=10
# [16]	validation_0-auc:0.90500	validation_1-auc:0.73978
# [21:00:54] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 980 extra nodes, 0 pruned nodes, max_depth=10
# [17]	validation_0-auc:0.90848	validation_1-auc:0.74234
# [21:00:59] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 810 extra nodes, 0 pruned nodes, max_depth=10
# [18]	validation_0-auc:0.91151	validation_1-auc:0.74564
# [21:01:04] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 892 extra nodes, 0 pruned nodes, max_depth=10
# [19]	validation_0-auc:0.91549	validation_1-auc:0.74858
# [21:01:10] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 944 extra nodes, 0 pruned nodes, max_depth=10
# [20]	validation_0-auc:0.91953	validation_1-auc:0.75194
# [21:01:15] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 956 extra nodes, 0 pruned nodes, max_depth=10
# [21]	validation_0-auc:0.92255	validation_1-auc:0.75459
# [21:01:21] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 962 extra nodes, 0 pruned nodes, max_depth=10
# [22]	validation_0-auc:0.92521	validation_1-auc:0.75658
# [21:01:26] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 812 extra nodes, 0 pruned nodes, max_depth=10
# [23]	validation_0-auc:0.92684	validation_1-auc:0.75880
# [21:01:34] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 854 extra nodes, 0 pruned nodes, max_depth=10
# [24]	validation_0-auc:0.92950	validation_1-auc:0.76156
# [21:01:40] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 814 extra nodes, 0 pruned nodes, max_depth=10
# [25]	validation_0-auc:0.93075	validation_1-auc:0.76373
# [21:01:45] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 818 extra nodes, 0 pruned nodes, max_depth=10
# [26]	validation_0-auc:0.93276	validation_1-auc:0.76623
# [21:01:51] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 772 extra nodes, 0 pruned nodes, max_depth=10
# [27]	validation_0-auc:0.93455	validation_1-auc:0.76841
# [21:01:57] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 920 extra nodes, 0 pruned nodes, max_depth=10
# [28]	validation_0-auc:0.93645	validation_1-auc:0.77034
# [21:02:03] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 936 extra nodes, 0 pruned nodes, max_depth=10
# [29]	validation_0-auc:0.93826	validation_1-auc:0.77130
# [21:02:09] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 940 extra nodes, 0 pruned nodes, max_depth=10
# [30]	validation_0-auc:0.94009	validation_1-auc:0.77332
# [21:02:15] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 814 extra nodes, 0 pruned nodes, max_depth=10
# [31]	validation_0-auc:0.94150	validation_1-auc:0.77622
# [21:02:22] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1014 extra nodes, 0 pruned nodes, max_depth=10
# [32]	validation_0-auc:0.94305	validation_1-auc:0.77732
# [21:02:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 910 extra nodes, 0 pruned nodes, max_depth=10
# [33]	validation_0-auc:0.94439	validation_1-auc:0.77847
# [21:02:36] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 996 extra nodes, 0 pruned nodes, max_depth=10
# [34]	validation_0-auc:0.94601	validation_1-auc:0.78016
# [21:02:43] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 964 extra nodes, 0 pruned nodes, max_depth=10
# [35]	validation_0-auc:0.94744	validation_1-auc:0.78116
# [21:02:51] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1010 extra nodes, 0 pruned nodes, max_depth=10
# [36]	validation_0-auc:0.94898	validation_1-auc:0.78196
# [21:02:58] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 858 extra nodes, 0 pruned nodes, max_depth=10
# [37]	validation_0-auc:0.95000	validation_1-auc:0.78258
# [21:03:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1022 extra nodes, 0 pruned nodes, max_depth=10
# [38]	validation_0-auc:0.95132	validation_1-auc:0.78436
# [21:03:13] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 846 extra nodes, 0 pruned nodes, max_depth=10
# [39]	validation_0-auc:0.95245	validation_1-auc:0.78596
# [21:03:20] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 946 extra nodes, 0 pruned nodes, max_depth=10
# [40]	validation_0-auc:0.95328	validation_1-auc:0.78652
# [21:03:26] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 820 extra nodes, 0 pruned nodes, max_depth=10
# [41]	validation_0-auc:0.95411	validation_1-auc:0.78766
# [21:03:32] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1058 extra nodes, 0 pruned nodes, max_depth=10
# [42]	validation_0-auc:0.95535	validation_1-auc:0.78919
# [21:03:37] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1000 extra nodes, 0 pruned nodes, max_depth=10
# [43]	validation_0-auc:0.95615	validation_1-auc:0.78966
# [21:03:43] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 894 extra nodes, 0 pruned nodes, max_depth=10
# [44]	validation_0-auc:0.95713	validation_1-auc:0.79090
# [21:03:48] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 960 extra nodes, 0 pruned nodes, max_depth=10
# [45]	validation_0-auc:0.95792	validation_1-auc:0.79138
# [21:03:53] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 916 extra nodes, 0 pruned nodes, max_depth=10
# [46]	validation_0-auc:0.95875	validation_1-auc:0.79243
# [21:03:59] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 958 extra nodes, 0 pruned nodes, max_depth=10
# [47]	validation_0-auc:0.95982	validation_1-auc:0.79395
# [21:04:04] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 986 extra nodes, 0 pruned nodes, max_depth=10
# [48]	validation_0-auc:0.96022	validation_1-auc:0.79467
# [21:04:10] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 916 extra nodes, 0 pruned nodes, max_depth=10
# [49]	validation_0-auc:0.96080	validation_1-auc:0.79589
# [21:04:15] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 836 extra nodes, 0 pruned nodes, max_depth=10
# [50]	validation_0-auc:0.96123	validation_1-auc:0.79685
# [21:04:21] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1084 extra nodes, 0 pruned nodes, max_depth=10
# [51]	validation_0-auc:0.96207	validation_1-auc:0.79830
# [21:04:26] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1096 extra nodes, 0 pruned nodes, max_depth=10
# [52]	validation_0-auc:0.96279	validation_1-auc:0.79884
# [21:04:31] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1006 extra nodes, 0 pruned nodes, max_depth=10
# [53]	validation_0-auc:0.96338	validation_1-auc:0.79975
# [21:04:37] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1062 extra nodes, 0 pruned nodes, max_depth=10
# [54]	validation_0-auc:0.96409	validation_1-auc:0.80044
# [21:04:42] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 770 extra nodes, 0 pruned nodes, max_depth=10
# [55]	validation_0-auc:0.96441	validation_1-auc:0.80137
# [21:04:50] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 980 extra nodes, 0 pruned nodes, max_depth=10
# [56]	validation_0-auc:0.96492	validation_1-auc:0.80188
# [21:04:56] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 896 extra nodes, 0 pruned nodes, max_depth=10
# [57]	validation_0-auc:0.96537	validation_1-auc:0.80239
# [21:05:01] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 928 extra nodes, 0 pruned nodes, max_depth=10
# [58]	validation_0-auc:0.96588	validation_1-auc:0.80300
# [21:05:07] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1078 extra nodes, 0 pruned nodes, max_depth=10
# [59]	validation_0-auc:0.96649	validation_1-auc:0.80346
# [21:05:12] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 862 extra nodes, 0 pruned nodes, max_depth=10
# [60]	validation_0-auc:0.96697	validation_1-auc:0.80374
# [21:05:17] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1036 extra nodes, 0 pruned nodes, max_depth=10
# [61]	validation_0-auc:0.96732	validation_1-auc:0.80442
# [21:05:23] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 706 extra nodes, 0 pruned nodes, max_depth=10
# [62]	validation_0-auc:0.96744	validation_1-auc:0.80484
# [21:05:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1064 extra nodes, 0 pruned nodes, max_depth=10
# [63]	validation_0-auc:0.96803	validation_1-auc:0.80525
# [21:05:33] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 874 extra nodes, 0 pruned nodes, max_depth=10
# [64]	validation_0-auc:0.96832	validation_1-auc:0.80559
# [21:05:39] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=10
# [65]	validation_0-auc:0.96871	validation_1-auc:0.80671
# [21:05:44] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1060 extra nodes, 0 pruned nodes, max_depth=10
# [66]	validation_0-auc:0.96904	validation_1-auc:0.80706
# [21:05:49] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1060 extra nodes, 0 pruned nodes, max_depth=10
# [67]	validation_0-auc:0.96942	validation_1-auc:0.80744
# [21:05:55] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 866 extra nodes, 0 pruned nodes, max_depth=10
# [68]	validation_0-auc:0.96979	validation_1-auc:0.80810
# [21:06:00] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1054 extra nodes, 0 pruned nodes, max_depth=10
# [69]	validation_0-auc:0.97010	validation_1-auc:0.80866
# [21:06:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 940 extra nodes, 0 pruned nodes, max_depth=10
# [70]	validation_0-auc:0.97051	validation_1-auc:0.80948
# [21:06:11] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 994 extra nodes, 0 pruned nodes, max_depth=10
# [71]	validation_0-auc:0.97084	validation_1-auc:0.81028
# [21:06:17] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 892 extra nodes, 0 pruned nodes, max_depth=10
# [72]	validation_0-auc:0.97114	validation_1-auc:0.81066
# [21:06:22] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1128 extra nodes, 0 pruned nodes, max_depth=10
# [73]	validation_0-auc:0.97139	validation_1-auc:0.81128
# [21:06:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 810 extra nodes, 0 pruned nodes, max_depth=10
# [74]	validation_0-auc:0.97168	validation_1-auc:0.81178
# [21:06:33] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1044 extra nodes, 0 pruned nodes, max_depth=10
# [75]	validation_0-auc:0.97208	validation_1-auc:0.81240
# [21:06:38] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 878 extra nodes, 0 pruned nodes, max_depth=10
# [76]	validation_0-auc:0.97234	validation_1-auc:0.81333
# [21:06:43] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 830 extra nodes, 0 pruned nodes, max_depth=10
# [77]	validation_0-auc:0.97242	validation_1-auc:0.81372
# [21:06:49] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 946 extra nodes, 0 pruned nodes, max_depth=10
# [78]	validation_0-auc:0.97269	validation_1-auc:0.81405
# [21:06:54] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1170 extra nodes, 0 pruned nodes, max_depth=10
# [79]	validation_0-auc:0.97300	validation_1-auc:0.81458
# [21:07:00] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 946 extra nodes, 0 pruned nodes, max_depth=10
# [80]	validation_0-auc:0.97326	validation_1-auc:0.81505
# [21:07:05] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 906 extra nodes, 0 pruned nodes, max_depth=10
# [81]	validation_0-auc:0.97348	validation_1-auc:0.81536
# [21:07:11] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1046 extra nodes, 0 pruned nodes, max_depth=10
# [82]	validation_0-auc:0.97365	validation_1-auc:0.81593
# [21:07:16] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 952 extra nodes, 0 pruned nodes, max_depth=10
# [83]	validation_0-auc:0.97379	validation_1-auc:0.81598
# [21:07:21] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 910 extra nodes, 0 pruned nodes, max_depth=10
# [84]	validation_0-auc:0.97403	validation_1-auc:0.81665
# [21:07:27] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 934 extra nodes, 0 pruned nodes, max_depth=10
# [85]	validation_0-auc:0.97428	validation_1-auc:0.81752
# [21:07:32] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 996 extra nodes, 0 pruned nodes, max_depth=10
# [86]	validation_0-auc:0.97442	validation_1-auc:0.81756
# [21:07:38] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1068 extra nodes, 0 pruned nodes, max_depth=10
# [87]	validation_0-auc:0.97462	validation_1-auc:0.81859
# [21:07:43] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1002 extra nodes, 0 pruned nodes, max_depth=10
# [88]	validation_0-auc:0.97487	validation_1-auc:0.81859
# [21:07:49] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1134 extra nodes, 0 pruned nodes, max_depth=10
# [89]	validation_0-auc:0.97501	validation_1-auc:0.81896
# [21:07:56] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 938 extra nodes, 0 pruned nodes, max_depth=10
# [90]	validation_0-auc:0.97526	validation_1-auc:0.81914
# [21:08:01] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1066 extra nodes, 0 pruned nodes, max_depth=10
# [91]	validation_0-auc:0.97550	validation_1-auc:0.81954
# [21:08:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 782 extra nodes, 0 pruned nodes, max_depth=10
# [92]	validation_0-auc:0.97562	validation_1-auc:0.81972
# [21:08:12] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 746 extra nodes, 0 pruned nodes, max_depth=10
# [93]	validation_0-auc:0.97568	validation_1-auc:0.81995
# [21:08:17] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1022 extra nodes, 0 pruned nodes, max_depth=10
# [94]	validation_0-auc:0.97584	validation_1-auc:0.82013
# [21:08:23] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 876 extra nodes, 0 pruned nodes, max_depth=10
# [95]	validation_0-auc:0.97591	validation_1-auc:0.82073
# [21:08:29] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 976 extra nodes, 0 pruned nodes, max_depth=10
# [96]	validation_0-auc:0.97605	validation_1-auc:0.82089
# [21:08:34] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 916 extra nodes, 0 pruned nodes, max_depth=10
# [97]	validation_0-auc:0.97619	validation_1-auc:0.82095
# [21:08:39] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 966 extra nodes, 0 pruned nodes, max_depth=10
# [98]	validation_0-auc:0.97631	validation_1-auc:0.82130
# [21:08:45] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 824 extra nodes, 0 pruned nodes, max_depth=10
# [99]	validation_0-auc:0.97642	validation_1-auc:0.82172
# [21:09:00] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 848 extra nodes, 0 pruned nodes, max_depth=10
# [0]	validation_0-auc:0.73177	validation_1-auc:0.60856
# [21:09:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 810 extra nodes, 0 pruned nodes, max_depth=10
# [1]	validation_0-auc:0.76169	validation_1-auc:0.64338
# [21:09:12] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 862 extra nodes, 0 pruned nodes, max_depth=10
# [2]	validation_0-auc:0.78542	validation_1-auc:0.65932
# [21:09:17] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 902 extra nodes, 0 pruned nodes, max_depth=10
# [3]	validation_0-auc:0.80856	validation_1-auc:0.67581
# [21:09:23] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 910 extra nodes, 0 pruned nodes, max_depth=10
# [4]	validation_0-auc:0.82201	validation_1-auc:0.68487
# [21:09:29] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 930 extra nodes, 0 pruned nodes, max_depth=10
# [5]	validation_0-auc:0.83407	validation_1-auc:0.69167
# [21:09:35] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 880 extra nodes, 0 pruned nodes, max_depth=10
# [6]	validation_0-auc:0.84204	validation_1-auc:0.69977
# [21:09:40] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 942 extra nodes, 0 pruned nodes, max_depth=10
# [7]	validation_0-auc:0.85048	validation_1-auc:0.70641
# [21:09:46] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 882 extra nodes, 0 pruned nodes, max_depth=10
# [8]	validation_0-auc:0.85911	validation_1-auc:0.71108
# [21:09:52] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 772 extra nodes, 0 pruned nodes, max_depth=10
# [9]	validation_0-auc:0.86539	validation_1-auc:0.71581
# [21:09:58] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 770 extra nodes, 0 pruned nodes, max_depth=10
# [10]	validation_0-auc:0.87144	validation_1-auc:0.71947
# [21:10:03] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 888 extra nodes, 0 pruned nodes, max_depth=10
# [11]	validation_0-auc:0.87762	validation_1-auc:0.72485
# [21:10:09] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 748 extra nodes, 0 pruned nodes, max_depth=10
# [12]	validation_0-auc:0.88258	validation_1-auc:0.72781
# [21:10:14] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 864 extra nodes, 0 pruned nodes, max_depth=10
# [13]	validation_0-auc:0.88841	validation_1-auc:0.73103
# [21:10:20] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 864 extra nodes, 0 pruned nodes, max_depth=10
# [14]	validation_0-auc:0.89358	validation_1-auc:0.73340
# [21:10:25] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 856 extra nodes, 0 pruned nodes, max_depth=10
# [15]	validation_0-auc:0.89772	validation_1-auc:0.73617
# [21:10:31] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1046 extra nodes, 0 pruned nodes, max_depth=10
# [16]	validation_0-auc:0.90204	validation_1-auc:0.73999
# [21:10:36] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 776 extra nodes, 0 pruned nodes, max_depth=10
# [17]	validation_0-auc:0.90475	validation_1-auc:0.74373
# [21:10:41] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 806 extra nodes, 0 pruned nodes, max_depth=10
# [18]	validation_0-auc:0.90836	validation_1-auc:0.74643
# [21:10:47] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 922 extra nodes, 0 pruned nodes, max_depth=10
# [19]	validation_0-auc:0.91216	validation_1-auc:0.74844
# [21:10:52] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 870 extra nodes, 0 pruned nodes, max_depth=10
# [20]	validation_0-auc:0.91503	validation_1-auc:0.75122
# [21:10:58] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 862 extra nodes, 0 pruned nodes, max_depth=10
# [21]	validation_0-auc:0.91786	validation_1-auc:0.75454
# [21:11:03] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=10
# [22]	validation_0-auc:0.92099	validation_1-auc:0.75646
# [21:11:08] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 804 extra nodes, 0 pruned nodes, max_depth=10
# [23]	validation_0-auc:0.92354	validation_1-auc:0.75849
# [21:11:13] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 876 extra nodes, 0 pruned nodes, max_depth=10
# [24]	validation_0-auc:0.92634	validation_1-auc:0.76070
# [21:11:19] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 852 extra nodes, 0 pruned nodes, max_depth=10
# [25]	validation_0-auc:0.92905	validation_1-auc:0.76227
# [21:11:24] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 922 extra nodes, 0 pruned nodes, max_depth=10
# [26]	validation_0-auc:0.93018	validation_1-auc:0.76309
# [21:11:29] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 966 extra nodes, 0 pruned nodes, max_depth=10
# [27]	validation_0-auc:0.93247	validation_1-auc:0.76419
# [21:11:34] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 790 extra nodes, 0 pruned nodes, max_depth=10
# [28]	validation_0-auc:0.93417	validation_1-auc:0.76555
# [21:11:40] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 918 extra nodes, 0 pruned nodes, max_depth=10
# [29]	validation_0-auc:0.93668	validation_1-auc:0.76712
# [21:11:45] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 778 extra nodes, 0 pruned nodes, max_depth=10
# [30]	validation_0-auc:0.93815	validation_1-auc:0.76924
# [21:11:50] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 828 extra nodes, 0 pruned nodes, max_depth=10
# [31]	validation_0-auc:0.93959	validation_1-auc:0.77088
# [21:11:56] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 856 extra nodes, 0 pruned nodes, max_depth=10
# [32]	validation_0-auc:0.94124	validation_1-auc:0.77233
# [21:12:01] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 966 extra nodes, 0 pruned nodes, max_depth=10
# [33]	validation_0-auc:0.94264	validation_1-auc:0.77331
# [21:12:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 756 extra nodes, 0 pruned nodes, max_depth=10
# [34]	validation_0-auc:0.94400	validation_1-auc:0.77505
# [21:12:12] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 872 extra nodes, 0 pruned nodes, max_depth=10
# [35]	validation_0-auc:0.94567	validation_1-auc:0.77641
# [21:12:17] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1036 extra nodes, 0 pruned nodes, max_depth=10
# [36]	validation_0-auc:0.94754	validation_1-auc:0.77749
# [21:12:23] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 876 extra nodes, 0 pruned nodes, max_depth=10
# [37]	validation_0-auc:0.94861	validation_1-auc:0.77849
# [21:12:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 972 extra nodes, 0 pruned nodes, max_depth=10
# [38]	validation_0-auc:0.94992	validation_1-auc:0.77892
# [21:12:33] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1016 extra nodes, 0 pruned nodes, max_depth=10
# [39]	validation_0-auc:0.95122	validation_1-auc:0.77984
# [21:12:39] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 990 extra nodes, 0 pruned nodes, max_depth=10
# [40]	validation_0-auc:0.95232	validation_1-auc:0.78111
# [21:12:44] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1202 extra nodes, 0 pruned nodes, max_depth=10
# [41]	validation_0-auc:0.95376	validation_1-auc:0.78207
# [21:12:49] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 786 extra nodes, 0 pruned nodes, max_depth=10
# [42]	validation_0-auc:0.95436	validation_1-auc:0.78338
# [21:12:55] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 784 extra nodes, 0 pruned nodes, max_depth=10
# [43]	validation_0-auc:0.95512	validation_1-auc:0.78445
# [21:13:00] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 912 extra nodes, 0 pruned nodes, max_depth=10
# [44]	validation_0-auc:0.95610	validation_1-auc:0.78560
# [21:13:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 914 extra nodes, 0 pruned nodes, max_depth=10
# [45]	validation_0-auc:0.95698	validation_1-auc:0.78656
# [21:13:11] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 874 extra nodes, 0 pruned nodes, max_depth=10
# [46]	validation_0-auc:0.95783	validation_1-auc:0.78746
# [21:13:16] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 920 extra nodes, 0 pruned nodes, max_depth=10
# [47]	validation_0-auc:0.95883	validation_1-auc:0.78867
# [21:13:22] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1228 extra nodes, 0 pruned nodes, max_depth=10
# [48]	validation_0-auc:0.96010	validation_1-auc:0.78957
# [21:13:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1100 extra nodes, 0 pruned nodes, max_depth=10
# [49]	validation_0-auc:0.96090	validation_1-auc:0.79020
# [21:13:34] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 892 extra nodes, 0 pruned nodes, max_depth=10
# [50]	validation_0-auc:0.96167	validation_1-auc:0.79097
# [21:13:39] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 884 extra nodes, 0 pruned nodes, max_depth=10
# [51]	validation_0-auc:0.96201	validation_1-auc:0.79127
# [21:13:45] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 994 extra nodes, 0 pruned nodes, max_depth=10
# [52]	validation_0-auc:0.96275	validation_1-auc:0.79288
# [21:13:50] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 880 extra nodes, 0 pruned nodes, max_depth=10
# [53]	validation_0-auc:0.96320	validation_1-auc:0.79361
# [21:13:56] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1002 extra nodes, 0 pruned nodes, max_depth=10
# [54]	validation_0-auc:0.96379	validation_1-auc:0.79472
# [21:14:01] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 812 extra nodes, 0 pruned nodes, max_depth=10
# [55]	validation_0-auc:0.96425	validation_1-auc:0.79530
# [21:14:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 952 extra nodes, 0 pruned nodes, max_depth=10
# [56]	validation_0-auc:0.96472	validation_1-auc:0.79611
# [21:14:11] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 882 extra nodes, 0 pruned nodes, max_depth=10
# [57]	validation_0-auc:0.96513	validation_1-auc:0.79724
# [21:14:17] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 812 extra nodes, 0 pruned nodes, max_depth=10
# [58]	validation_0-auc:0.96560	validation_1-auc:0.79791
# [21:14:22] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1090 extra nodes, 0 pruned nodes, max_depth=10
# [59]	validation_0-auc:0.96600	validation_1-auc:0.79831
# [21:14:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 856 extra nodes, 0 pruned nodes, max_depth=10
# [60]	validation_0-auc:0.96633	validation_1-auc:0.79927
# [21:14:33] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1070 extra nodes, 0 pruned nodes, max_depth=10
# [61]	validation_0-auc:0.96697	validation_1-auc:0.79991
# [21:14:39] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1052 extra nodes, 0 pruned nodes, max_depth=10
# [62]	validation_0-auc:0.96750	validation_1-auc:0.80088
# [21:14:44] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 760 extra nodes, 0 pruned nodes, max_depth=10
# [63]	validation_0-auc:0.96783	validation_1-auc:0.80193
# [21:14:50] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 916 extra nodes, 0 pruned nodes, max_depth=10
# [64]	validation_0-auc:0.96829	validation_1-auc:0.80232
# [21:14:55] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 956 extra nodes, 0 pruned nodes, max_depth=10
# [65]	validation_0-auc:0.96870	validation_1-auc:0.80287
# [21:15:01] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 928 extra nodes, 0 pruned nodes, max_depth=10
# [66]	validation_0-auc:0.96902	validation_1-auc:0.80360
# [21:15:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1028 extra nodes, 0 pruned nodes, max_depth=10
# [67]	validation_0-auc:0.96937	validation_1-auc:0.80395
# [21:15:11] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 828 extra nodes, 0 pruned nodes, max_depth=10
# [68]	validation_0-auc:0.96963	validation_1-auc:0.80431
# [21:15:17] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 824 extra nodes, 0 pruned nodes, max_depth=10
# [69]	validation_0-auc:0.96998	validation_1-auc:0.80499
# [21:15:22] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=10
# [70]	validation_0-auc:0.97028	validation_1-auc:0.80480
# [21:15:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1172 extra nodes, 0 pruned nodes, max_depth=10
# [71]	validation_0-auc:0.97080	validation_1-auc:0.80554
# [21:15:33] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 946 extra nodes, 0 pruned nodes, max_depth=10
# [72]	validation_0-auc:0.97116	validation_1-auc:0.80631
# [21:15:39] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1040 extra nodes, 0 pruned nodes, max_depth=10
# [73]	validation_0-auc:0.97160	validation_1-auc:0.80684
# [21:15:44] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 958 extra nodes, 0 pruned nodes, max_depth=10
# [74]	validation_0-auc:0.97196	validation_1-auc:0.80713
# [21:15:50] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1048 extra nodes, 0 pruned nodes, max_depth=10
# [75]	validation_0-auc:0.97229	validation_1-auc:0.80757
# [21:15:55] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 960 extra nodes, 0 pruned nodes, max_depth=10
# [76]	validation_0-auc:0.97265	validation_1-auc:0.80806
# [21:16:01] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=10
# [77]	validation_0-auc:0.97283	validation_1-auc:0.80858
# [21:16:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 994 extra nodes, 0 pruned nodes, max_depth=10
# [78]	validation_0-auc:0.97318	validation_1-auc:0.80899
# [21:16:12] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1014 extra nodes, 0 pruned nodes, max_depth=10
# [79]	validation_0-auc:0.97344	validation_1-auc:0.80946
# [21:16:17] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 1040 extra nodes, 0 pruned nodes, max_depth=10
# [80]	validation_0-auc:0.97372	validation_1-auc:0.81008
# [21:16:23] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 884 extra nodes, 0 pruned nodes, max_depth=10
# [81]	validation_0-auc:0.97394	validation_1-auc:0.81039
# [21:16:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 960 extra nodes, 0 pruned nodes, max_depth=10
# [82]	validation_0-auc:0.97411	validation_1-auc:0.81065
# [21:16:33] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 916 extra nodes, 0 pruned nodes, max_depth=10
# [83]	validation_0-auc:0.97432	validation_1-auc:0.81101
# [21:16:38] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 866 extra nodes, 0 pruned nodes, max_depth=10
# [84]	validation_0-auc:0.97446	validation_1-auc:0.81162
# ...
# [22:41:35] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [145]	validation_0-auc:0.91354	validation_1-auc:0.84782
# [22:41:38] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [146]	validation_0-auc:0.91387	validation_1-auc:0.84820
# [22:41:41] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [147]	validation_0-auc:0.91422	validation_1-auc:0.84854
# [22:41:45] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [148]	validation_0-auc:0.91471	validation_1-auc:0.84868
# [22:41:47] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [149]	validation_0-auc:0.91518	validation_1-auc:0.84917
# [22:41:50] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [150]	validation_0-auc:0.91549	validation_1-auc:0.84950
# [22:41:54] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [151]	validation_0-auc:0.91578	validation_1-auc:0.84966
# [22:41:57] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [152]	validation_0-auc:0.91622	validation_1-auc:0.84987
# [22:41:59] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [153]	validation_0-auc:0.91650	validation_1-auc:0.85013
# [22:42:03] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [154]	validation_0-auc:0.91688	validation_1-auc:0.85053
# [22:42:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [155]	validation_0-auc:0.91724	validation_1-auc:0.85085
# [22:42:09] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [156]	validation_0-auc:0.91764	validation_1-auc:0.85115
# [22:42:12] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [157]	validation_0-auc:0.91800	validation_1-auc:0.85170
# [22:42:16] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [158]	validation_0-auc:0.91827	validation_1-auc:0.85187
# [22:42:19] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [159]	validation_0-auc:0.91862	validation_1-auc:0.85215
# [22:42:22] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [160]	validation_0-auc:0.91890	validation_1-auc:0.85227
# [22:42:25] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [161]	validation_0-auc:0.91933	validation_1-auc:0.85253
# [22:42:28] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [162]	validation_0-auc:0.91964	validation_1-auc:0.85292
# [22:42:31] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [163]	validation_0-auc:0.91992	validation_1-auc:0.85327
# [22:42:34] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [164]	validation_0-auc:0.92040	validation_1-auc:0.85369
# [22:42:38] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [165]	validation_0-auc:0.92082	validation_1-auc:0.85403
# [22:42:41] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [166]	validation_0-auc:0.92123	validation_1-auc:0.85411
# [22:42:44] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [167]	validation_0-auc:0.92158	validation_1-auc:0.85430
# [22:42:47] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [168]	validation_0-auc:0.92195	validation_1-auc:0.85454
# [22:42:51] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [169]	validation_0-auc:0.92231	validation_1-auc:0.85471
# [22:42:54] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [170]	validation_0-auc:0.92255	validation_1-auc:0.85490
# [22:42:57] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [171]	validation_0-auc:0.92273	validation_1-auc:0.85497
# [22:43:00] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [172]	validation_0-auc:0.92313	validation_1-auc:0.85524
# [22:43:03] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [173]	validation_0-auc:0.92343	validation_1-auc:0.85550
# [22:43:06] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [174]	validation_0-auc:0.92373	validation_1-auc:0.85578
# [22:43:10] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [175]	validation_0-auc:0.92406	validation_1-auc:0.85589
# [22:43:13] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [176]	validation_0-auc:0.92444	validation_1-auc:0.85624
# [22:43:16] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [177]	validation_0-auc:0.92478	validation_1-auc:0.85666
# [22:43:19] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [178]	validation_0-auc:0.92507	validation_1-auc:0.85682
# [22:43:23] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [179]	validation_0-auc:0.92543	validation_1-auc:0.85706
# [22:43:26] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=5
# [180]	validation_0-auc:0.92578	validation_1-auc:0.85727
# [22:43:29] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [181]	validation_0-auc:0.92616	validation_1-auc:0.85753
# [22:43:32] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [182]	validation_0-auc:0.92633	validation_1-auc:0.85757
# [22:43:36] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [183]	validation_0-auc:0.92674	validation_1-auc:0.85779
# [22:43:39] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [184]	validation_0-auc:0.92706	validation_1-auc:0.85801
# [22:43:42] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [185]	validation_0-auc:0.92740	validation_1-auc:0.85824
# [22:43:45] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [186]	validation_0-auc:0.92758	validation_1-auc:0.85837
# [22:43:48] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [187]	validation_0-auc:0.92771	validation_1-auc:0.85836
# [22:43:52] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [188]	validation_0-auc:0.92811	validation_1-auc:0.85873
# [22:43:55] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=5
# [189]	validation_0-auc:0.92839	validation_1-auc:0.85898
# [22:43:58] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [190]	validation_0-auc:0.92865	validation_1-auc:0.85910
# [22:44:01] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [191]	validation_0-auc:0.92898	validation_1-auc:0.85940
# [22:44:04] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [192]	validation_0-auc:0.92920	validation_1-auc:0.85947
# [22:44:07] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [193]	validation_0-auc:0.92945	validation_1-auc:0.85958
# [22:44:11] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [194]	validation_0-auc:0.92963	validation_1-auc:0.85960
# [22:44:14] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [195]	validation_0-auc:0.92998	validation_1-auc:0.85983
# [22:44:17] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [196]	validation_0-auc:0.93019	validation_1-auc:0.86012
# [22:44:20] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [197]	validation_0-auc:0.93043	validation_1-auc:0.86024
# [22:44:23] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=5
# [198]	validation_0-auc:0.93086	validation_1-auc:0.86056
# [22:44:27] INFO: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=5
# [199]	validation_0-auc:0.93112	validation_1-auc:0.86062
# RandomizedSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, gamma=None,
#                                            gpu_id=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate=0.01, max_bin=None,
#                                            max_c...
#                                            max_delta_step=None, max_depth=None,
#                                            max_leaves=None,
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            n_estimators=100, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=47,
#                                            reg_alpha=None, reg_lambda=None, ...),
#                    n_iter=2,
#                    param_distributions={'learning_rate': [0.05, 0.1],
#                                         'max_depth': [5, 10],
#                                         'n_estimators': [50, 100, 200]},
#                    scoring='roc_auc', verbose=1)

# %%
print(xgbc_clf.best_score_)
print(xgbc_clf.best_params_)
print(xgbc_clf.best_estimator_)
# Out:
# 0.8679341370465286
# {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.05}
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.05, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=5, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=200,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=47,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred2=xgbc_clf.predict(X_test_all)
sub_df = pd.DataFrame({"ID_code":X_test_all.index.map(lambda x: 'test_{}'.format(x))})
sub_df["target"] = y_pred2
sub_df.to_csv("KaggleSubm.csv", index=False)

# %%
y_proba = xgbc_clf.predict_proba(X_test_all)

kag = pd.DataFrame({
    'ID_code': X_test_all.index.map(lambda x: 'test_{}'.format(x)),
    'target': y_proba[:,1]})
kag = kag.set_index('ID_code')
kag.to_csv('Kag_sub.csv')

# %%
import pickle as pkl
# save model to file
#pkl.dump(xgbc_clf, open("xgb.pkl.dat", "wb"))
# load model from file
model = pkl.load(open("xgb.pkl.dat", "rb"))

# %%
xgbc_score, xgbc_scores

# %%
xgbc_clf.fit(X_train, y_train)

# %%
# print(xgbc_clf.best_score_)
# print(xgbc_clf.best_params_)
print(model.best_score_)
print(model.best_params_)
# Out:
# 0.8679341370465286
# {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.05}

# %%
# inputs model, X_val and y_val to plot confusion matrix
def show_confusion_matrix(model, X_val, y_val):
    print('Confusion Matrix')
    plot_confusion_matrix(model, X_val, y_val)
    plt.show()
    y_pred = model.predict(X_val)
    print(classification_report(y_val, y_pred))

    print('Accuracy of the model: ',  accuracy_score(y_val, y_pred))
    print('Recall of the model: ',    recall_score(y_val, y_pred))
    print('Precision of the model: ', precision_score(y_val, y_pred))
    print('F Measure of the model: ', f1_score(y_val, y_pred))

# %%
show_confusion_matrix(model, X_val, y_val):
# Out:
# XGBoost Classifier - Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.89      0.92     35980
#          1.0       0.39      0.63      0.48      4020
#
#     accuracy                           0.86     40000
#    macro avg       0.67      0.76      0.70     40000
# weighted avg       0.90      0.86      0.88     40000
#
# Accuracy of the model:  0.862525
# Recall of the model:  0.6328358208955224
# Precision of the model:  0.3873915029693924
# F Measure of the model:  0.4805894020969113

# %%
# inputs model, X_val and y_val to plot RoC curve
def plot_roc(model, X_val, y_val):
    # calculate the fpr and tpr for 
    # all thresholds of the classification
    preds = model.predict_proba(X_val)[:,1]
    fpr, tpr, threshold = metrics.roc_curve(y_val, preds)
    roc_auc = metrics.auc(fpr, tpr)

    # Plot
    plt.title('Receiver Operating Characteristic - Stacked Ensemble Model')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([-0.1, 1.1])
    plt.ylim([0, 1.1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
plot_roc(model, X_val, y_val)
